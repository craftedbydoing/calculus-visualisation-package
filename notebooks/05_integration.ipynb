# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import numpy as np

from calc_package.core.functions import sample_clean
from calc_package.core.integration import riemann_sum
from calc_package.plotting.integration import plot_riemann
from calc_package.widgets.integration import riemann_visualisation

# %%
f = lambda x: 3 + 0*x
a = 0
b = 1
n = 3

riemann_sum(f, a, b, n)
# Out:
# (array([0.        , 0.33333333, 0.66666667, 1.        ]),
#  array([3., 3., 3.]),
#  0.3333333333333333,
#  np.float64(3.0))

# %%
f = lambda x: np.exp(x)
a = 0
b = np.pi
n = 10

x, f_vals = sample_clean(f, (a,b))
edges, heights, width, sumation = riemann_sum(f, a, b, n, "midpoint")

fig, ax = plt.subplots()
plot_riemann(ax, x, f_vals, edges[:-1], heights, width)
print(sumation)
# Out:
# 22.04990410319539

# %%
# %matplotlib widget
riemann_visualisation()
# Out:
# interactive(children=(Dropdown(description='func_name', options=('e^x',), value='e^x'), IntSlider(value=4, des…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
