# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

from calc_package.core.series import taylor_values
from calc_package.widgets.series import taylor_explorer

# %%
np.zeros((2,1))
# Out:
# array([[0.],
#        [0.]])

# %%
math.factorial(0)
# Out:
# 1

# %%
x = np.linspace(-3,5, 500)
deriv = lambda k, x: np.exp(x) + 0*k
a = 2
n = 4

f = lambda x: np.exp(x)
f_vals = f(x)
plt.plot(x, taylor_values(x, a, deriv, n))
plt.plot(x, f_vals)

# %%
k = 1
a = 1-k%2
b = 1-((k+1)%2)
c = (-1)**(k%4)

print(f"{c} [ {a} x sin(x) + {b} x cos(x) ]")
# Out:
# -1 [ 0 x sin(x) + 1 x cos(x) ]

# %%
# %matplotlib widget
taylor_explorer()
# Out:
# interactive(children=(Dropdown(description='func_name', options=('e^x', 'sin(x)', '1/(1-x)', 'x^2'), value='e^…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
